# %% [markdown]
# # Week 4 - Final Handoff
#
# This notebook runs the Week 4 final reporting workflow and previews the final dashboard summary table.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

from finalize_week4 import main
from config import WEEK4_DASHBOARD_SUMMARY_PATH, WEEK4_EXECUTIVE_SUMMARY_PATH, WEEK4_FINAL_REPORT_PATH

main()
dashboard_summary = pd.read_csv(WEEK4_DASHBOARD_SUMMARY_PATH)
dashboard_summary

# %% [markdown]
# Generated Week 4 outputs:
#
# - `data/processed/week4_dashboard_summary.csv`
# - `reports/week4_executive_summary.md`
# - `reports/week4_final_business_report.md`
# - `reports/week4_final_presentation.pptx`
