# %% [markdown]
# # Week 3 - Baseline Predictive Modeling
#
# This notebook runs the production modeling pipeline for cancellation prediction.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

from predictive_modeling import run_modeling
from config import MODEL_METRICS_PATH, MODEL_FEATURE_IMPORTANCE_PATH, MODELING_REPORT_PATH

run_modeling()
metrics = pd.read_csv(MODEL_METRICS_PATH)
feature_importance = pd.read_csv(MODEL_FEATURE_IMPORTANCE_PATH)
metrics

# %% [markdown]
# ## Top Predictive Features

# %%
feature_importance.head(15)

# %% [markdown]
# Generated outputs:
#
# - `reports/week3_modeling_report.md`
# - `data/processed/week3_model_metrics.csv`
# - `data/processed/week3_feature_importance.csv`
# - `visualizations/22_week3_roc_curve.png`
# - `visualizations/23_week3_confusion_matrix_logistic_regression.png`
# - `visualizations/23_week3_confusion_matrix_decision_tree.png`
# - `visualizations/24_week3_feature_importance.png`
